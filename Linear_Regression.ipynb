# %%
# Import 
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %%
temps =[18.3, 13.5, 35.7, 69.9]
daylight = [7.6, 9.2, 13.4, 12.3]

# %%
plt.scatter(daylight, temps)
plt.xlabel("Hours of Daylight")
plt.ylabel("Average Monthly Temperature")
plt.show()

# %%
linregress(daylight, temps)
# Out:
# LinregressResult(slope=6.527031700288185, intercept=-34.99971181556196, rvalue=0.686941366225257, pvalue=0.3130586337747431, stderr=4.882518430953862)

# %%
(slope, intercept, rval, pval, stderr) = linregress(daylight, temps)

# %%
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
# Out:
# y = 6.53x + -35.0

# %%
regress_values = [(day * slope + intercept) for day in daylight]

# %%
plt.scatter(daylight,temps)
plt.plot(daylight,regress_values, "r")
plt.xlabel("Hours of Daylight")
plt.ylabel("Average Monthly Temperatures")
plt.show()
